# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import trimesh
import networkx as nx

# %%
g = gpd.read_file('cd_us.shp')['geometry'][5]

t = trimesh.creation.extrude_polygon(g,1)
t.show()
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <title>trimesh: threejs viewer</title>
#     <meta charset=&quot;utf-8&quot;>
#     <meta name=&quot;viewport&quot; content=&quot;width=device-width,
# 		   user-scalable=no,
# 		   minimum-scale=1.0,
# 		   maximum-scale=1.0&quot;>
#     <style>
#       body {
#       margin: 0px;
#       overflow: hidden;
#       }
#     </style>
#   </head>
#   <body>
#     <div id=&quot;container&quot;></div>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/three.js/92/three.min.js&quot;></script>
# ...

# %%
for c  in f:
    for i in range(3):
        plt.plot([ v[c[i]][0],v[c[(i+1)%3]][0]    ],[v[c[i]][1],v[c[(i+1)%3]][1]      ],linestyle='-')

# %%
for a in v:
    plt.plot(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe0fc1584fac> in <module>()
# ----> 1 for a in v:
#       2     plt.plot(a)
#
# NameError: name 'v' is not defined

# %%
G=trimesh.graph.vertex_adjacency_graph(trimesh.Trimesh(t[0],t[1][:2000]))

# %%
nx.draw(G, node_size=1)
